# %%
# 연습문제 7.1.1

from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
sy = pd.Series(iris.target, dtype='category')
sy = sy.cat.rename_categories(iris.target_names)
df['species'] = sy

df["petal length (cm)"].hist()

# %%
df[df.species == "setosa"]["petal length (cm)"].hist()
plt.title("꽃잎 길이의 히스토그램")
plt.show()

# %%
sns.distplot(df["petal length (cm)"], rug=True)
plt.title = ('연습문제7.1.1.2')
plt.xlabel('petal length (cm)')
plt.show()

# %%
sns.distplot(df[df.species == "setosa"]["petal length (cm)"], rug=True)
plt.title = ('연습문제7.1.1.2')
plt.xlabel('petal length (cm)')
plt.show()

# %%
list_x_mean = []
for i in range(50):
    x = np.random.normal(size=100)
    x_mean = x.mean()
    list_x_mean.append(x_mean)

# %%
plt.subplot(121)
sns.distplot(x)
plt.xlim(-5, 5)
plt.subplot(122)
sns.distplot(list_x_mean)
plt.xlim(-5, 5)
plt.show()
